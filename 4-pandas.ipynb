# %% [markdown]
# # Pandas

# %%
import pandas as pd

# %%
hotels = pd.read_csv("hotel_booking_data.csv")

# %%
hotels.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 36 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
hotels.shape
# Out:
# (119390, 36)

# %%
hotels.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  customer_type  \
# 0                        0                     0       2  ...      Transient
# ...

# %%
hotels.tail()
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 119385             August                        35
# 119386             August                        35
# 119387             August                        35
# 119388             August                        35
# 119389             August                        35
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 119385                         30                        2
# 119386                         31                        2
# 119387                         31                        2
# ...

# %%
hotels.describe().T
# Out:
#                                    count         mean         std      min  \
# is_canceled                     119390.0     0.370416    0.482918     0.00
# lead_time                       119390.0   104.011416  106.863097     0.00
# arrival_date_year               119390.0  2016.156554    0.707476  2015.00
# arrival_date_week_number        119390.0    27.165173   13.605138     1.00
# arrival_date_day_of_month       119390.0    15.798241    8.780829     1.00
# stays_in_weekend_nights         119390.0     0.927599    0.998613     0.00
# stays_in_week_nights            119390.0     2.500302    1.908286     0.00
# adults                          119390.0     1.856403    0.579261     0.00
# children                        119386.0     0.103890    0.398561     0.00
# babies                          119390.0     0.007949    0.097436     0.00
# is_repeated_guest               119390.0     0.031912    0.175767     0.00
# ...

# %%
hotels.sample(5)
# Out:
#               hotel  is_canceled  lead_time  arrival_date_year  \
# 89570    City Hotel            0         57               2016
# 90586    City Hotel            0          0               2016
# 10350  Resort Hotel            1         49               2017
# 40486    City Hotel            1         25               2015
# 30846  Resort Hotel            0          6               2016
#
#       arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 89570                May                        21                         21
# 90586               June                        24                          8
# 10350           February                         9                         28
# 40486               July                        31                         27
# 30846           December                        50                          4
#
#        stays_in_weekend_nights  stays_in_week_nights  adults  ...  \
# ...

# %%
hotels.isna().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
hotels.count()
# Out:
# hotel                             119390
# is_canceled                       119390
# lead_time                         119390
# arrival_date_year                 119390
# arrival_date_month                119390
# arrival_date_week_number          119390
# arrival_date_day_of_month         119390
# stays_in_weekend_nights           119390
# stays_in_week_nights              119390
# adults                            119390
# children                          119386
# babies                            119390
# meal                              119390
# country                           118902
# market_segment                    119390
# distribution_channel              119390
# is_repeated_guest                 119390
# previous_cancellations            119390
# previous_bookings_not_canceled    119390
# reserved_room_type                119390
# assigned_room_type                119390
# booking_changes                   119390
# deposit_type                      119390
# ...

# %%
hotels["hotel"]
# Out:
# 0         Resort Hotel
# 1         Resort Hotel
# 2         Resort Hotel
# 3         Resort Hotel
# 4         Resort Hotel
#               ...
# 119385      City Hotel
# 119386      City Hotel
# 119387      City Hotel
# 119388      City Hotel
# 119389      City Hotel
# Name: hotel, Length: 119390, dtype: object

# %%
hotels["hotel"].unique()
# Out:
# array(['Resort Hotel', 'City Hotel'], dtype=object)

# %%
hotels["stays_in_week_nights"].mean()
# Out:
# 2.500301532791691

# %%
hotels["stays_in_week_nights"].describe()
# Out:
# count    119390.000000
# mean          2.500302
# std           1.908286
# min           0.000000
# 25%           1.000000
# 50%           2.000000
# 75%           3.000000
# max          50.000000
# Name: stays_in_week_nights, dtype: float64

# %%
hotels.groupby(["hotel"]).mean()
# Out:
#               is_canceled   lead_time  arrival_date_year  \
# hotel
# City Hotel       0.417270  109.735724        2016.174285
# Resort Hotel     0.277634   92.675686        2016.121443
#
#               arrival_date_week_number  arrival_date_day_of_month  \
# hotel
# City Hotel                   27.177449                  15.786625
# Resort Hotel                 27.140864                  15.821243
#
#               stays_in_weekend_nights  stays_in_week_nights    adults  \
# hotel
# City Hotel                   0.795185              2.182957  1.850977
# Resort Hotel                 1.189815              3.128732  1.867149
#
#               children    babies  is_repeated_guest  previous_cancellations  \
# hotel
# City Hotel    0.091370  0.004941           0.025615                0.079743
# Resort Hotel  0.128682  0.013904           0.044383                0.101722
#
#               previous_bookings_not_canceled  booking_changes       agent  \
# hotel
# ...

# %%
hotels.groupby(["hotel"]).describe()["children"]
# Out:
#                 count      mean       std  min  25%  50%  75%   max
# hotel
# City Hotel    79326.0  0.091370  0.372177  0.0  0.0  0.0  0.0   3.0
# Resort Hotel  40060.0  0.128682  0.445195  0.0  0.0  0.0  0.0  10.0

# %%
hotels["children"].mode()
# Out:
# 0    0.0
# dtype: float64

# %%
hotels["children"] > 2
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 119385    False
# 119386    False
# 119387    False
# 119388    False
# 119389    False
# Name: children, Length: 119390, dtype: bool

# %% [markdown]
# ## Exercises

# %%
len(hotels)
# Out:
# 119390

# %%
hotels.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
hotels["country"].value_counts()[0:5]
# Out:
# PRT    48590
# GBR    12129
# FRA    10415
# ESP     8568
# DEU     7287
# Name: country, dtype: int64

# %%
hotels["adr"].mean()
# Out:
# 101.83112153446686

# %%
hotels["total_nights"] = hotels["stays_in_week_nights"] + hotels["stays_in_weekend_nights"]

round(hotels["total_nights"].mean(),2)
# Out:
# 3.43

# %%
hotels['total_paid'] = hotels['adr'] * hotels['total_nights']

round(hotels['total_paid'].mean(),2)
# Out:
# 357.85

# %%
hotels[hotels['total_of_special_requests'] == 5][['name','email','phone-number']]
# Out:
#                           name                          email  phone-number
# 7860             Amanda Harper           Amanda.H66@yahoo.com  864-257-9807
# 11125            Laura Sanders      Sanders_Laura@hotmail.com  120-754-3942
# 14596              Tommy Ortiz            Tommy_O@hotmail.com  377-098-5937
# 14921           Gilbert Miller         Miller.Gilbert@aol.com  806-574-2045
# 14922           Timothy Torres         TTorres@protonmail.com  422-113-4918
# 24630          Jennifer Weaver             Jennifer_W@aol.com  341-150-8437
# 27288           Crystal Horton             Crystal.H@mail.com  736-187-2543
# 27477           Brittney Burke       Burke_Brittney16@att.com  825-860-3212
# 29906          Cynthia Cabrera    Cabrera.Cynthia@xfinity.com  280-973-9357
# 29949              Sarah Floyd              Sarah_F@gmail.com  100-586-7149
# 32267           Michelle Villa         Michelle.Villa@aol.com  494-968-0905
# ...

# %%
hotels['is_repeated_guest'] / hotels['total_of_special_requests'] * 100
# Out:
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         0.0
#          ...
# 119385    NaN
# 119386    0.0
# 119387    0.0
# 119388    NaN
# 119389    0.0
# Length: 119390, dtype: float64

# %%
hotels['children_babies'] = hotels['children'] + hotels['babies']

hotels.sort_values('children_babies',ascending=False)[['name','children_babies','children','babies']][0:5]
# Out:
#                      name  children_babies  children  babies
# 328         Jamie Ramirez             10.0      10.0       0
# 46619     Nicholas Parker             10.0       0.0      10
# 78656       Marc Robinson              9.0       0.0       9
# 19718   Mr. Jeffrey Cross              3.0       3.0       0
# 107837      Albert French              3.0       1.0       2
